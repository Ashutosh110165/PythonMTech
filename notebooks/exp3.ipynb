# %% [markdown]
# # Python Programming Laboratory
#
# ## Experiment 3: Conditional Statements
#
# ### Aim
#
# To understand the use of conditional statements such as `if`, `if-else` and `if-elif-else` in Python.
#
# ### Introduction
#
# Conditional statements help a program make decisions based on different conditions. They allow different blocks of code to execute depending on whether a condition is true or false.

# %% [markdown]
# ## Program 1
#
# Write a Python program to check whether a number is positive, negative or zero.
# The number we are using is -3.

# %%
number = int(input("Enter a number: "))

if number > 0:
    print("Positive Number")
elif number < 0:
    print("Negative Number")
else:
    print("Zero")
# Out:
# Negative Number

# %% [markdown]
# The program uses `if-elif-else` statements to determine whether the entered number is positive, negative or zero.

# %% [markdown]
# ## Program 2
#
# Write a Python program to check whether a number is even or odd.
# The number we used is 230.

# %%
number = int(input("Enter a number: "))

if number % 2 == 0:
    print("Even Number")
else:
    print("Odd Number")
# Out:
# Even Number

# %% [markdown]
# ## Program 3
#
# Write a Python program to find the largest among three numbers.
# Three numbers that we used are 4,23,981.

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))

if a >= b and a >= c:
    print("Largest Number =", a)
elif b >= a and b >= c:
    print("Largest Number =", b)
else:
    print("Largest Number =", c)
# Out:
# Largest Number = 981

# %% [markdown]
# ## Program 4
#
# Write a Python program to check whether a year is a leap year.
# The year is 2004(my birth year).

# %%
year = int(input("Enter a year: "))

if (year % 400 == 0) or (year % 4 == 0 and year % 100 != 0):
    print(year, "is a Leap Year")
else:
    print(year, "is not a Leap Year")
# Out:
# 2004 is a Leap Year

# %% [markdown]
# ## Program 5
#
# Write a Python program to display the grade based on marks.
# The marks we got is 88.

# %%
marks = int(input("Enter marks: "))

if marks >= 90:
    print("Grade A")
elif marks >= 80:
    print("Grade B")
elif marks >= 70:
    print("Grade C")
elif marks >= 60:
    print("Grade D")
elif marks >= 40:
    print("Grade E")
else:
    print("Fail")
# Out:
# Grade B

# %% [markdown]
# ## Conclusion
#
# In this experiment, we learned how conditional statements are used to make decisions in Python programs. The `if`, `if-else` and `if-elif-else` statements help solve different real-life decision-making problems.
